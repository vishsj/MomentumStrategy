# %%
import requests
import json
import os

# %%
# def executeSomething():
#     #code here
    
i = 0

while True:
    outputFileName = 'optionChainData/output_'+'_'.join(map(str,list(time.localtime())[:6]))+'.txt'
    cookieCMD = 'curl -v -A "Mozilla" --cookie "USER_TOKEN=Yes" --cookie-jar nse-cookies.txt https://www.nseindia.com/'
    url_ = 'curl -v -A "Mozilla" --cookie nse-cookies.txt https://www.nseindia.com/api/option-chain-indices?symbol=NIFTY -o '+outputFileName
    os.system(cookieCMD)
    os.system(url_)
    print(outputFileName)
    i+=1
    time.sleep(60)
# Out:
# optionChainData/output_2020_9_25_10_20_35.txt
# optionChainData/output_2020_9_25_10_21_36.txt
# optionChainData/output_2020_9_25_10_22_37.txt
# optionChainData/output_2020_9_25_10_23_38.txt
# optionChainData/output_2020_9_25_10_24_40.txt
# optionChainData/output_2020_9_25_10_25_41.txt
# optionChainData/output_2020_9_25_10_26_42.txt
# optionChainData/output_2020_9_25_10_27_43.txt
# optionChainData/output_2020_9_25_10_28_44.txt
# optionChainData/output_2020_9_25_10_29_44.txt
# optionChainData/output_2020_9_25_10_30_45.txt
# optionChainData/output_2020_9_25_10_31_46.txt
# optionChainData/output_2020_9_25_10_32_47.txt
# optionChainData/output_2020_9_25_10_33_48.txt
# optionChainData/output_2020_9_25_10_34_49.txt
# optionChainData/output_2020_9_25_10_35_50.txt
# optionChainData/output_2020_9_25_10_36_51.txt
# optionChainData/output_2020_9_25_10_37_51.txt
# optionChainData/output_2020_9_25_10_38_52.txt
# optionChainData/output_2020_9_25_10_39_53.txt
# ...
